# %% [markdown]
# # Pandas

# %% [markdown]
# Тьюториалы:
# - http://byumcl.bitbucket.org/bootcamp2013/labs/pandas.html
# - http://pandas.pydata.org/pandas-docs/stable/10min.html
# - https://www.kaggle.com/c/titanic/details/getting-started-with-python-ii
#
# Примеры:
# - http://pandas.pydata.org/pandas-docs/stable/cookbook.html#cookbook
#
# Если нужно что-то более специальное -- смотрите в документации
# - http://pandas.pydata.org/pandas-docs/stable/index.html

# %% [markdown]
# Рассмотрим сэмпл из данных по авиарейсам в США за январь-апрель 2008 года.
#
#
# Полный датасет можно найти здесь: http://stat-computing.org/dataexpo/2009/2008.csv.bz2
#
# Описание: http://stat-computing.org/dataexpo/2009/the-data.html

# %%
import pandas as pd

# %%
data = pd.read_csv('flights.csv')
data.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4    926.0         930   1054.0
# 4  2008      1           3          4   1829.0        1755   1959.0
#
#    CRSArrTime UniqueCarrier  FlightNum        ...         TaxiIn  TaxiOut  \
# 0        2225            WN        335        ...            4.0      8.0
# 1        1000            WN       3231        ...            5.0     10.0
# 2         750            WN        448        ...            3.0     17.0
# 3        1100            WN       1746        ...            3.0      7.0
# 4        1925            WN       3920        ...            3.0     10.0
#
#    Cancelled  CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# 0          0               NaN         0           NaN          NaN      NaN
# 1          0               NaN         0           NaN          NaN      NaN
# 2          0               NaN         0           NaN          NaN      NaN
# 3          0               NaN         0           NaN          NaN      NaN
# 4          0               NaN         0           2.0          0.0      0.0
#
#    SecurityDelay  LateAircraftDelay
# 0            NaN                NaN
# 1            NaN                NaN
# 2            NaN                NaN
# 3            NaN                NaN
# 4            0.0               32.0
#
# [5 rows x 29 columns]

# %%
data.columns
# Out:
# Index(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime',
#        'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum', 'TailNum',
#        'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %%
data.shape
# Out:
# (7009728, 29)

# %%
data['Distance'].head()
# Out:
# 0    810
# 1    810
# 2    515
# 3    515
# 4    515
# Name: Distance, dtype: int64

# %%
data.Distance

# %%
data['CancellationCode'].unique()
# Out:
# array([nan, 'A', 'C', 'B', 'D'], dtype=object)

# %%
data[['DepDelay', 'ArrDelay']][:10]
# Out:
#    DepDelay  ArrDelay
# 0       8.0     -14.0
# 1      19.0       2.0
# 2       8.0      14.0
# 3      -4.0      -6.0
# 4      34.0      34.0
# 5      25.0      11.0
# 6      67.0      57.0
# 7      -1.0     -18.0
# 8       2.0       2.0
# 9       0.0     -16.0

# %%
data[:10, 1:4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-79b9c5d58192> in <module>()
# ----> 1 data[:10, 1:4]
#
# /Users/rysmiatova/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# /Users/rysmiatova/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# /Users/rysmiatova/anaconda3/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1641         """Return the cached item, item represents a label indexer."""
#    1642         cache = self._item_cache
# -> 1643         res = cache.get(item)
#    1644         if res is None:
#    1645             values = self._data.get(item)
#
# TypeError: unhashable type: 'slice'

# %% [markdown]
# Слайсы по столбцам и строкам:

# %%
data.iloc[:10, 1:4]
# Out:
#    Month  DayofMonth  DayOfWeek
# 0      1           3          4
# 1      1           3          4
# 2      1           3          4
# 3      1           3          4
# 4      1           3          4
# 5      1           3          4
# 6      1           3          4
# 7      1           3          4
# 8      1           3          4
# 9      1           3          4

# %%
data.loc[data.Month == 8]
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 4232106  2008      8           2          6   1402.0        1400   1831.0
# 4232107  2008      8           2          6   1811.0        1745   2240.0
# 4232108  2008      8           2          6    658.0         700   1129.0
# 4232109  2008      8           2          6   1113.0        1055   1827.0
# 4232110  2008      8           2          6   1007.0        1000   1524.0
# 4232111  2008      8           2          6   1534.0        1535   2048.0
# 4232112  2008      8           2          6    840.0         840   1351.0
# 4232113  2008      8           2          6    558.0         600   1113.0
# 4232114  2008      8           2          6   1348.0        1350   1907.0
# 4232115  2008      8           2          6   1741.0        1740   2255.0
# 4232116  2008      8           2          6    659.0         700   1216.0
# 4232117  2008      8           2          6    932.0         925   1712.0
# 4232118  2008      8           2          6   1100.0        1045   1603.0
# 4232119  2008      8           2          6   2004.0        1935   2146.0
# 4232120  2008      8           2          6   1701.0        1705   1848.0
# 4232121  2008      8           2          6   1431.0        1435   1613.0
# 4232122  2008      8           2          6    627.0         625    827.0
# 4232123  2008      8           2          6   1259.0        1245   1441.0
# 4232124  2008      8           2          6    904.0         905   1049.0
# 4232125  2008      8           2          6   1820.0        1735   2224.0
# 4232126  2008      8           2          6   1420.0        1420   1823.0
# 4232127  2008      8           2          6    853.0         850   1301.0
# 4232128  2008      8           2          6   1702.0        1610   2126.0
# 4232129  2008      8           2          6   1836.0        1830   2253.0
# 4232130  2008      8           2          6   1027.0        1030   1459.0
# 4232131  2008      8           2          6   1342.0        1340   1439.0
# 4232132  2008      8           2          6    646.0         650    744.0
# 4232133  2008      8           2          6    931.0         925   1030.0
# 4232134  2008      8           2          6   1652.0        1640   1748.0
# 4232135  2008      8           2          6    814.0         815    912.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 4844355  2008      8          16          6   1132.0        1140   1803.0
# 4844356  2008      8          16          6   1252.0        1256   1406.0
# 4844357  2008      8          16          6   1020.0        1022   1135.0
# 4844358  2008      8          16          6   1150.0        1040   1319.0
# 4844359  2008      8          16          6   1313.0        1258   1258.0
# 4844360  2008      8          16          6     35.0        2345    552.0
# 4844361  2008      8          16          6    737.0         745    929.0
# 4844362  2008      8          16          6   1439.0        1446   1554.0
# 4844363  2008      8          16          6    808.0         815   1016.0
# 4844364  2008      8          16          6    606.0         610    742.0
# 4844365  2008      8          16          6    832.0         835    938.0
# 4844366  2008      8          16          6   1654.0        1659   1919.0
# 4844367  2008      8          16          6    704.0         705    909.0
# 4844368  2008      8          16          6   1732.0        1721   1919.0
# 4844369  2008      8          16          6    718.0         720    825.0
# 4844370  2008      8          16          6   2012.0        2002   2100.0
# 4844371  2008      8          16          6    758.0         805    904.0
# 4844372  2008      8          16          6   1312.0        1315   1623.0
# 4844373  2008      8          16          6      NaN        2050      NaN
# 4844374  2008      8          16          6   1407.0        1409   1606.0
# 4844375  2008      8          16          6    822.0         824    959.0
# 4844376  2008      8          16          6   1103.0        1052   1526.0
# 4844377  2008      8          16          6   1005.0        1005   1559.0
# 4844378  2008      8          16          6    855.0         855   1038.0
# 4844379  2008      8          16          6   1644.0        1645   2216.0
# 4844380  2008      8          16          6    825.0         830    947.0
# 4844381  2008      8          16          6   1447.0        1450   2017.0
# 4844382  2008      8          16          6    703.0         700   1007.0
# 4844383  2008      8          16          6    638.0         645   1014.0
# 4844384  2008      8          16          6   1102.0        1105   1217.0
#
#          CRSArrTime UniqueCarrier  FlightNum        ...         TaxiIn  \
# 4232106        1840            WN        584        ...            4.0
# 4232107        2220            WN       1649        ...            5.0
# 4232108        1135            WN       1650        ...            4.0
# 4232109        1815            WN        607        ...            7.0
# 4232110        1525            WN         60        ...            4.0
# 4232111        2055            WN        743        ...            5.0
# 4232112        1400            WN       1556        ...            5.0
# 4232113        1120            WN       2638        ...            4.0
# 4232114        1915            WN       3028        ...           10.0
# 4232115        2300            WN       3173        ...            5.0
# 4232116        1220            WN       3996        ...            4.0
# 4232117        1725            WN       3467        ...            3.0
# 4232118        1550            WN        757        ...            5.0
# 4232119        2130            WN       1021        ...            4.0
# 4232120        1900            WN       1710        ...            5.0
# 4232121        1630            WN       1899        ...            5.0
# 4232122         830            WN       2447        ...            8.0
# 4232123        1445            WN       3118        ...            5.0
# 4232124        1110            WN       3439        ...            5.0
# 4232125        2145            WN       1198        ...            3.0
# 4232126        1835            WN       1345        ...            3.0
# 4232127        1305            WN       3354        ...            3.0
# 4232128        2045            WN        314        ...            3.0
# 4232129        2305            WN       2930        ...            2.0
# 4232130        1510            WN       3524        ...            2.0
# 4232131        1450            WN        132        ...            5.0
# 4232132         800            WN        159        ...            4.0
# 4232133        1040            WN        392        ...            4.0
# 4232134        1745            WN       1540        ...            4.0
# 4232135         930            WN       2397        ...            4.0
# ...             ...           ...        ...        ...            ...
# 4844355        1827            DL       1714        ...            5.0
# 4844356        1409            DL       1715        ...           14.0
# 4844357        1129            DL       1716        ...           11.0
# 4844358        1210            DL       1717        ...            9.0
# 4844359        1248            DL       1717        ...            3.0
# 4844360         524            DL       1720        ...            5.0
# 4844361        1005            DL       1721        ...            8.0
# 4844362        1609            DL       1722        ...            6.0
# 4844363        1004            DL       1724        ...           32.0
# 4844364         750            DL       1727        ...            6.0
# 4844365         942            DL       1727        ...            6.0
# 4844366        1913            DL       1728        ...           18.0
# 4844367         902            DL       1729        ...            6.0
# 4844368        1909            DL       1730        ...           14.0
# 4844369         833            DL       1731        ...           11.0
# 4844370        2057            DL       1732        ...            5.0
# 4844371         911            DL       1733        ...           12.0
# 4844372        1610            DL       1735        ...            7.0
# 4844373         517            DL       1736        ...            NaN
# 4844374        1558            DL       1737        ...            5.0
# 4844375        1000            DL       1738        ...           11.0
# 4844376        1458            DL       1740        ...            7.0
# 4844377        1537            DL       1742        ...           14.0
# 4844378        1032            DL       1743        ...           13.0
# 4844379        2237            DL       1744        ...            9.0
# 4844380         943            DL       1745        ...           28.0
# 4844381        2013            DL       1746        ...            6.0
# 4844382        1017            DL       1747        ...            8.0
# 4844383        1011            DL       1748        ...           28.0
# 4844384        1216            DL       1748        ...           10.0
#
#          TaxiOut  Cancelled  CancellationCode  Diverted  CarrierDelay  \
# 4232106      6.0          0               NaN         0           NaN
# 4232107      5.0          0               NaN         0           0.0
# 4232108      8.0          0               NaN         0           NaN
# 4232109      5.0          0               NaN         0           NaN
# 4232110     10.0          0               NaN         0           NaN
# 4232111      6.0          0               NaN         0           NaN
# 4232112      6.0          0               NaN         0           NaN
# 4232113      9.0          0               NaN         0           NaN
# 4232114      9.0          0               NaN         0           NaN
# 4232115     10.0          0               NaN         0           NaN
# 4232116     10.0          0               NaN         0           NaN
# 4232117      7.0          0               NaN         0           NaN
# 4232118      7.0          0               NaN         0           NaN
# 4232119      7.0          0               NaN         0           5.0
# 4232120     10.0          0               NaN         0           NaN
# 4232121      6.0          0               NaN         0           NaN
# 4232122     19.0          0               NaN         0           NaN
# 4232123      5.0          0               NaN         0           NaN
# 4232124      8.0          0               NaN         0           NaN
# 4232125      6.0          0               NaN         0           5.0
# 4232126      7.0          0               NaN         0           NaN
# 4232127     11.0          0               NaN         0           NaN
# 4232128     10.0          0               NaN         0           0.0
# 4232129      6.0          0               NaN         0           NaN
# 4232130     10.0          0               NaN         0           NaN
# 4232131      5.0          0               NaN         0           NaN
# 4232132      6.0          0               NaN         0           NaN
# 4232133      9.0          0               NaN         0           NaN
# 4232134      5.0          0               NaN         0           NaN
# 4232135      7.0          0               NaN         0           NaN
# ...          ...        ...               ...       ...           ...
# 4844355     15.0          0               NaN         0           NaN
# 4844356      9.0          0               NaN         0           NaN
# 4844357     13.0          0               NaN         0           NaN
# 4844358     17.0          0               NaN         0          69.0
# 4844359     10.0          0               NaN         0           NaN
# 4844360     15.0          0               NaN         0          28.0
# 4844361     16.0          0               NaN         0           NaN
# 4844362     15.0          0               NaN         0           NaN
# 4844363     11.0          0               NaN         0           NaN
# 4844364     15.0          0               NaN         0           NaN
# 4844365     21.0          0               NaN         0           NaN
# 4844366      7.0          0               NaN         0           NaN
# 4844367     17.0          0               NaN         0           NaN
# 4844368     12.0          0               NaN         0           NaN
# 4844369     10.0          0               NaN         0           NaN
# 4844370     15.0          0               NaN         0           NaN
# 4844371     16.0          0               NaN         0           NaN
# 4844372     21.0          0               NaN         0           NaN
# 4844373      NaN          1                 A         0           NaN
# 4844374     11.0          0               NaN         0           NaN
# 4844375     22.0          0               NaN         0           NaN
# 4844376     26.0          0               NaN         0           0.0
# 4844377     38.0          0               NaN         0           0.0
# 4844378     14.0          0               NaN         0           NaN
# 4844379     16.0          0               NaN         0           NaN
# 4844380     10.0          0               NaN         0           NaN
# 4844381     11.0          0               NaN         0           NaN
# 4844382     33.0          0               NaN         0           NaN
# 4844383     13.0          0               NaN         0           NaN
# 4844384     20.0          0               NaN         0           NaN
#
#         WeatherDelay NASDelay  SecurityDelay  LateAircraftDelay
# 4232106          NaN      NaN            NaN                NaN
# 4232107          0.0      0.0            0.0               20.0
# 4232108          NaN      NaN            NaN                NaN
# 4232109          NaN      NaN            NaN                NaN
# 4232110          NaN      NaN            NaN                NaN
# 4232111          NaN      NaN            NaN                NaN
# 4232112          NaN      NaN            NaN                NaN
# 4232113          NaN      NaN            NaN                NaN
# 4232114          NaN      NaN            NaN                NaN
# 4232115          NaN      NaN            NaN                NaN
# 4232116          NaN      NaN            NaN                NaN
# 4232117          NaN      NaN            NaN                NaN
# 4232118          NaN      NaN            NaN                NaN
# 4232119          0.0      0.0            0.0               11.0
# 4232120          NaN      NaN            NaN                NaN
# 4232121          NaN      NaN            NaN                NaN
# 4232122          NaN      NaN            NaN                NaN
# 4232123          NaN      NaN            NaN                NaN
# 4232124          NaN      NaN            NaN                NaN
# 4232125          0.0      0.0            0.0               34.0
# 4232126          NaN      NaN            NaN                NaN
# 4232127          NaN      NaN            NaN                NaN
# 4232128          0.0      0.0            0.0               41.0
# 4232129          NaN      NaN            NaN                NaN
# 4232130          NaN      NaN            NaN                NaN
# 4232131          NaN      NaN            NaN                NaN
# 4232132          NaN      NaN            NaN                NaN
# 4232133          NaN      NaN            NaN                NaN
# 4232134          NaN      NaN            NaN                NaN
# 4232135          NaN      NaN            NaN                NaN
# ...              ...      ...            ...                ...
# 4844355          NaN      NaN            NaN                NaN
# 4844356          NaN      NaN            NaN                NaN
# 4844357          NaN      NaN            NaN                NaN
# 4844358          0.0      0.0            0.0                0.0
# 4844359          NaN      NaN            NaN                NaN
# 4844360          0.0      0.0            0.0                0.0
# 4844361          NaN      NaN            NaN                NaN
# 4844362          NaN      NaN            NaN                NaN
# 4844363          NaN      NaN            NaN                NaN
# 4844364          NaN      NaN            NaN                NaN
# 4844365          NaN      NaN            NaN                NaN
# 4844366          NaN      NaN            NaN                NaN
# 4844367          NaN      NaN            NaN                NaN
# 4844368          NaN      NaN            NaN                NaN
# 4844369          NaN      NaN            NaN                NaN
# 4844370          NaN      NaN            NaN                NaN
# 4844371          NaN      NaN            NaN                NaN
# 4844372          NaN      NaN            NaN                NaN
# 4844373          NaN      NaN            NaN                NaN
# 4844374          NaN      NaN            NaN                NaN
# 4844375          NaN      NaN            NaN                NaN
# 4844376          0.0     17.0            0.0               11.0
# 4844377          0.0     22.0            0.0                0.0
# 4844378          NaN      NaN            NaN                NaN
# 4844379          NaN      NaN            NaN                NaN
# 4844380          NaN      NaN            NaN                NaN
# 4844381          NaN      NaN            NaN                NaN
# 4844382          NaN      NaN            NaN                NaN
# 4844383          NaN      NaN            NaN                NaN
# 4844384          NaN      NaN            NaN                NaN
#
# [612279 rows x 29 columns]

# %% [markdown]
# #### Группировка данных

# %%
data.groupby('UniqueCarrier')

# %%
data.Cancelled.unique()
# Out:
# array([0, 1])

# %%
data.Origin.value_counts()
# Out:
# ATL    414513
# ORD    350380
# DFW    281281
# DEN    241443
# LAX    215608
# PHX    199408
# IAH    185172
# LAS    172876
# DTW    161989
# SFO    140587
# SLC    139088
# EWR    138506
# MCO    130872
# MSP    130289
# CLT    126045
# LGA    119135
# JFK    118804
# BOS    117915
# SEA    109069
# BWI    104074
# PHL    100499
# SAN     93775
# CVG     91265
# MDW     87619
# DCA     86662
# MEM     80966
# TPA     78179
# IAD     76031
# FLL     67177
# CLE     65795
#         ...
# OTH       515
# LMT       511
# SLE       486
# ACK       457
# STX       436
# MKG       396
# YKM       340
# ALO       323
# CMX       318
# RFD       290
# BPT       276
# WYS       264
# PLN       264
# RHI       221
# TEX       194
# LWB       185
# HTS       158
# ITH       132
# SUX       122
# BLI       120
# DLG       116
# ACY       116
# AKN       116
# ADK       102
# GST        85
# BJI        74
# INL        72
# TUP        10
# PIR         5
# PUB         2
# Name: Origin, dtype: int64

# %%
data.groupby('Cancelled')['Origin'].count()
# Out:
# Cancelled
# 0    6872294
# 1     137434
# Name: Origin, dtype: int64

# %%
data.groupby('Cancelled')['Origin'].describe()
# Out:
# Cancelled
# 0          count     6872294
#            unique        303
#            top           ATL
#            freq       408683
# 1          count      137434
#            unique        300
#            top           ORD
#            freq        15050
# dtype: object

# %%
data.groupby('Cancelled')['CancellationCode'].value_counts()
# Out:
# Cancelled  CancellationCode
# 1          B                   54904
#            A                   54330
#            C                   28188
#            D                      12
# dtype: int64

# %% [markdown]
# #### Объединение данных

# %%
carrier = data[data['CancellationCode'] == 'A']
weather = data[data['CancellationCode'] == 'B']

# %%
pd.concat([carrier, weather]).head()
# Out:
#      Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 178  2008      1           3          4      NaN         700      NaN
# 373  2008      1           3          4      NaN        1100      NaN
# 399  2008      1           3          4      NaN         905      NaN
# 415  2008      1           3          4      NaN        1930      NaN
# 676  2008      1           3          4      NaN         845      NaN
#
#      CRSArrTime UniqueCarrier  FlightNum        ...         TaxiIn  TaxiOut  \
# 178         830            WN        126        ...            NaN      NaN
# 373        1215            WN       1146        ...            NaN      NaN
# 399        1025            WN        469        ...            NaN      NaN
# 415        2035            WN       2528        ...            NaN      NaN
# 676        1140            WN        437        ...            NaN      NaN
#
#      Cancelled  CancellationCode  Diverted  CarrierDelay WeatherDelay  \
# 178          1                 A         0           NaN          NaN
# 373          1                 A         0           NaN          NaN
# 399          1                 A         0           NaN          NaN
# 415          1                 A         0           NaN          NaN
# 676          1                 A         0           NaN          NaN
#
#     NASDelay  SecurityDelay  LateAircraftDelay
# 178      NaN            NaN                NaN
# 373      NaN            NaN                NaN
# 399      NaN            NaN                NaN
# 415      NaN            NaN                NaN
# 676      NaN            NaN                NaN
#
# [5 rows x 29 columns]

# %%
pd.concat([carrier[:3], weather]).head()
# Out:
#       Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 178   2008      1           3          4      NaN         700      NaN
# 373   2008      1           3          4      NaN        1100      NaN
# 399   2008      1           3          4      NaN         905      NaN
# 2730  2008      1           4          5      NaN         925      NaN
# 3675  2008      1           4          5      NaN        1730      NaN
#
#       CRSArrTime UniqueCarrier  FlightNum        ...         TaxiIn  TaxiOut  \
# 178          830            WN        126        ...            NaN      NaN
# 373         1215            WN       1146        ...            NaN      NaN
# 399         1025            WN        469        ...            NaN      NaN
# 2730        1040            WN       1408        ...            NaN      NaN
# 3675        1850            WN        675        ...            NaN      NaN
#
#       Cancelled  CancellationCode  Diverted  CarrierDelay WeatherDelay  \
# 178           1                 A         0           NaN          NaN
# 373           1                 A         0           NaN          NaN
# 399           1                 A         0           NaN          NaN
# 2730          1                 B         0           NaN          NaN
# 3675          1                 B         0           NaN          NaN
#
#      NASDelay  SecurityDelay  LateAircraftDelay
# 178       NaN            NaN                NaN
# 373       NaN            NaN                NaN
# 399       NaN            NaN                NaN
# 2730      NaN            NaN                NaN
# 3675      NaN            NaN                NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# #### Пропуски в данных

# %%
data['CarrierDelay'][:10]
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     2.0
# 5     NaN
# 6    10.0
# 7     NaN
# 8     NaN
# 9     NaN
# Name: CarrierDelay, dtype: float64

# %%
data['CarrierDelay'].describe()
# Out:
# count    1.524735e+06
# mean     1.577206e+01
# std      4.009912e+01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      1.600000e+01
# max      2.436000e+03
# Name: CarrierDelay, dtype: float64

# %%
data['CarrierDelay'].isnull()[:10]
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4    False
# 5     True
# 6    False
# 7     True
# 8     True
# 9     True
# Name: CarrierDelay, dtype: bool

# %%
data[data['CarrierDelay'].isnull()][:10]
# Out:
#     Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0   2008      1           3          4   2003.0        1955   2211.0
# 1   2008      1           3          4    754.0         735   1002.0
# 2   2008      1           3          4    628.0         620    804.0
# 3   2008      1           3          4    926.0         930   1054.0
# 5   2008      1           3          4   1940.0        1915   2121.0
# 7   2008      1           3          4   1039.0        1040   1132.0
# 8   2008      1           3          4    617.0         615    652.0
# 9   2008      1           3          4   1620.0        1620   1639.0
# 10  2008      1           3          4    706.0         700    916.0
# 12  2008      1           3          4   1426.0        1430   1426.0
#
#     CRSArrTime UniqueCarrier  FlightNum        ...         TaxiIn  TaxiOut  \
# 0         2225            WN        335        ...            4.0      8.0
# 1         1000            WN       3231        ...            5.0     10.0
# 2          750            WN        448        ...            3.0     17.0
# 3         1100            WN       1746        ...            3.0      7.0
# 5         2110            WN        378        ...            4.0     10.0
# 7         1150            WN        535        ...            7.0      7.0
# 8          650            WN         11        ...            6.0     19.0
# 9         1655            WN        810        ...            3.0      6.0
# 10         915            WN        100        ...            5.0     19.0
# 12        1425            WN        829        ...            9.0     12.0
#
#     Cancelled  CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# 0           0               NaN         0           NaN          NaN      NaN
# 1           0               NaN         0           NaN          NaN      NaN
# 2           0               NaN         0           NaN          NaN      NaN
# 3           0               NaN         0           NaN          NaN      NaN
# 5           0               NaN         0           NaN          NaN      NaN
# 7           0               NaN         0           NaN          NaN      NaN
# 8           0               NaN         0           NaN          NaN      NaN
# 9           0               NaN         0           NaN          NaN      NaN
# 10          0               NaN         0           NaN          NaN      NaN
# 12          0               NaN         0           NaN          NaN      NaN
#
#     SecurityDelay  LateAircraftDelay
# 0             NaN                NaN
# 1             NaN                NaN
# 2             NaN                NaN
# 3             NaN                NaN
# 5             NaN                NaN
# 7             NaN                NaN
# 8             NaN                NaN
# 9             NaN                NaN
# 10            NaN                NaN
# 12            NaN                NaN
#
# [10 rows x 29 columns]

# %%
import numpy as np

# %%
data.index = range(data.shape[0])

# %%
data
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0        2008      1           3          4   2003.0        1955   2211.0
# 1        2008      1           3          4    754.0         735   1002.0
# 2        2008      1           3          4    628.0         620    804.0
# 3        2008      1           3          4    926.0         930   1054.0
# 4        2008      1           3          4   1829.0        1755   1959.0
# 5        2008      1           3          4   1940.0        1915   2121.0
# 6        2008      1           3          4   1937.0        1830   2037.0
# 7        2008      1           3          4   1039.0        1040   1132.0
# 8        2008      1           3          4    617.0         615    652.0
# 9        2008      1           3          4   1620.0        1620   1639.0
# 10       2008      1           3          4    706.0         700    916.0
# 11       2008      1           3          4   1644.0        1510   1845.0
# 12       2008      1           3          4   1426.0        1430   1426.0
# 13       2008      1           3          4    715.0         715    720.0
# 14       2008      1           3          4   1702.0        1700   1651.0
# 15       2008      1           3          4   1029.0        1020   1021.0
# 16       2008      1           3          4   1452.0        1425   1640.0
# 17       2008      1           3          4    754.0         745    940.0
# 18       2008      1           3          4   1323.0        1255   1526.0
# 19       2008      1           3          4   1416.0        1325   1512.0
# 20       2008      1           3          4    706.0         705    807.0
# 21       2008      1           3          4   1657.0        1625   1754.0
# 22       2008      1           3          4   1900.0        1840   1956.0
# 23       2008      1           3          4   1039.0        1030   1133.0
# 24       2008      1           3          4    801.0         800    902.0
# 25       2008      1           3          4   1520.0        1455   1619.0
# 26       2008      1           3          4   1422.0        1255   1657.0
# 27       2008      1           3          4   1954.0        1925   2239.0
# 28       2008      1           3          4    636.0         635    921.0
# 29       2008      1           3          4    734.0         730    958.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 7009698  2008     12          13          6   1625.0        1635   1744.0
# 7009699  2008     12          13          6   1254.0        1221   1420.0
# 7009700  2008     12          13          6   1842.0        1845   1953.0
# 7009701  2008     12          13          6   1528.0        1500   1720.0
# 7009702  2008     12          13          6   1531.0        1522   1822.0
# 7009703  2008     12          13          6   1910.0        1910   2017.0
# 7009704  2008     12          13          6   1441.0        1445   1604.0
# 7009705  2008     12          13          6    921.0         830   1112.0
# 7009706  2008     12          13          6   1435.0        1440   1701.0
# 7009707  2008     12          13          6   1750.0        1755   2010.0
# 7009708  2008     12          13          6    706.0         710    850.0
# 7009709  2008     12          13          6   1552.0        1520   1735.0
# 7009710  2008     12          13          6   1250.0        1220   1617.0
# 7009711  2008     12          13          6   1033.0        1041   1255.0
# 7009712  2008     12          13          6    840.0         843   1025.0
# 7009713  2008     12          13          6    810.0         815   1504.0
# 7009714  2008     12          13          6    547.0         545    646.0
# 7009715  2008     12          13          6    848.0         850   1024.0
# 7009716  2008     12          13          6    936.0         936   1114.0
# 7009717  2008     12          13          6    657.0         600    904.0
# 7009718  2008     12          13          6   1007.0         847   1149.0
# 7009719  2008     12          13          6    638.0         640    808.0
# 7009720  2008     12          13          6    756.0         800   1032.0
# 7009721  2008     12          13          6    612.0         615    923.0
# 7009722  2008     12          13          6    749.0         750    901.0
# 7009723  2008     12          13          6   1002.0         959   1204.0
# 7009724  2008     12          13          6    834.0         835   1021.0
# 7009725  2008     12          13          6    655.0         700    856.0
# 7009726  2008     12          13          6   1251.0        1240   1446.0
# 7009727  2008     12          13          6   1110.0        1103   1413.0
#
#          CRSArrTime UniqueCarrier  FlightNum        ...         TaxiIn  \
# 0              2225            WN        335        ...            4.0
# 1              1000            WN       3231        ...            5.0
# 2               750            WN        448        ...            3.0
# 3              1100            WN       1746        ...            3.0
# 4              1925            WN       3920        ...            3.0
# 5              2110            WN        378        ...            4.0
# 6              1940            WN        509        ...            3.0
# 7              1150            WN        535        ...            7.0
# 8               650            WN         11        ...            6.0
# 9              1655            WN        810        ...            3.0
# 10              915            WN        100        ...            5.0
# 11             1725            WN       1333        ...            6.0
# 12             1425            WN        829        ...            9.0
# 13              710            WN       1016        ...            7.0
# 14             1655            WN       1827        ...            4.0
# 15             1010            WN       2272        ...            6.0
# 16             1625            WN        675        ...            7.0
# 17              955            WN       1144        ...            5.0
# 18             1510            WN          4        ...            4.0
# 19             1435            WN         54        ...            2.0
# 20              810            WN         68        ...            3.0
# 21             1735            WN        623        ...            5.0
# 22             1950            WN        717        ...            2.0
# 23             1140            WN       1244        ...            2.0
# 24              910            WN       2101        ...            3.0
# 25             1605            WN       2553        ...            2.0
# 26             1610            WN        188        ...            6.0
# 27             2235            WN       1754        ...            3.0
# 28              945            WN       2275        ...            5.0
# 29             1020            WN        550        ...            2.0
# ...             ...           ...        ...        ...            ...
# 7009698        1758            DL       1605        ...           12.0
# 7009699        1359            DL       1609        ...            9.0
# 7009700        2006            DL       1610        ...            8.0
# 7009701        1642            DL       1611        ...            4.0
# 7009702        1823            DL       1612        ...            9.0
# 7009703        2016            DL       1612        ...            5.0
# 7009704        1622            DL       1613        ...            8.0
# 7009705        1008            DL       1616        ...            8.0
# 7009706        1704            DL       1618        ...           20.0
# 7009707        2015            DL       1618        ...            7.0
# 7009708         837            DL       1619        ...           23.0
# 7009709        1718            DL       1620        ...            9.0
# 7009710        1552            DL       1621        ...            9.0
# 7009711        1303            DL       1622        ...            9.0
# 7009712        1021            DL       1624        ...            6.0
# 7009713        1526            DL       1625        ...            7.0
# 7009714         650            DL       1627        ...            8.0
# 7009715        1005            DL       1628        ...            4.0
# 7009716        1119            DL       1630        ...            4.0
# 7009717         749            DL       1631        ...           15.0
# 7009718        1010            DL       1631        ...            8.0
# 7009719         753            DL       1632        ...           14.0
# 7009720        1026            DL       1633        ...           23.0
# 7009721         907            DL       1635        ...            5.0
# 7009722         859            DL       1636        ...           20.0
# 7009723        1150            DL       1636        ...            6.0
# 7009724        1023            DL       1637        ...            5.0
# 7009725         856            DL       1638        ...           24.0
# 7009726        1437            DL       1639        ...           13.0
# 7009727        1418            DL       1641        ...            8.0
#
#          TaxiOut  Cancelled  CancellationCode  Diverted  CarrierDelay  \
# 0            8.0          0               NaN         0           NaN
# 1           10.0          0               NaN         0           NaN
# 2           17.0          0               NaN         0           NaN
# 3            7.0          0               NaN         0           NaN
# 4           10.0          0               NaN         0           2.0
# 5           10.0          0               NaN         0           NaN
# 6            7.0          0               NaN         0          10.0
# 7            7.0          0               NaN         0           NaN
# 8           19.0          0               NaN         0           NaN
# 9            6.0          0               NaN         0           NaN
# 10          19.0          0               NaN         0           NaN
# 11           8.0          0               NaN         0           8.0
# 12          12.0          0               NaN         0           NaN
# 13          21.0          0               NaN         0           NaN
# 14          10.0          0               NaN         0           NaN
# 15           9.0          0               NaN         0           NaN
# 16           8.0          0               NaN         0           3.0
# 17          16.0          0               NaN         0           NaN
# 18           9.0          0               NaN         0           0.0
# 19           5.0          0               NaN         0          12.0
# 20           7.0          0               NaN         0           NaN
# 21           5.0          0               NaN         0           7.0
# 22           5.0          0               NaN         0           NaN
# 23           5.0          0               NaN         0           NaN
# 24           5.0          0               NaN         0           NaN
# 25           7.0          0               NaN         0           NaN
# 26           6.0          0               NaN         0          40.0
# 27           7.0          0               NaN         0           NaN
# 28          13.0          0               NaN         0           NaN
# 29           8.0          0               NaN         0           NaN
# ...          ...        ...               ...       ...           ...
# 7009698     21.0          0               NaN         0           NaN
# 7009699     13.0          0               NaN         0           0.0
# 7009700     11.0          0               NaN         0           NaN
# 7009701     29.0          0               NaN         0          16.0
# 7009702     14.0          0               NaN         0           NaN
# 7009703     24.0          0               NaN         0           NaN
# 7009704     10.0          0               NaN         0           NaN
# 7009705     21.0          0               NaN         0          51.0
# 7009706     10.0          0               NaN         0           NaN
# 7009707     20.0          0               NaN         0           NaN
# 7009708     32.0          0               NaN         0           NaN
# 7009709      7.0          0               NaN         0           0.0
# 7009710     18.0          0               NaN         0           3.0
# 7009711     15.0          0               NaN         0           NaN
# 7009712     46.0          0               NaN         0           NaN
# 7009713     17.0          0               NaN         0           NaN
# 7009714     13.0          0               NaN         0           NaN
# 7009715     44.0          0               NaN         0           0.0
# 7009716     24.0          0               NaN         0           NaN
# 7009717     34.0          0               NaN         0           0.0
# 7009718     32.0          0               NaN         0           1.0
# 7009719     26.0          0               NaN         0           0.0
# 7009720     17.0          0               NaN         0           NaN
# 7009721     23.0          0               NaN         0           0.0
# 7009722     11.0          0               NaN         0           NaN
# 7009723     45.0          0               NaN         0           NaN
# 7009724     23.0          0               NaN         0           NaN
# 7009725     12.0          0               NaN         0           NaN
# 7009726     13.0          0               NaN         0           NaN
# 7009727     11.0          0               NaN         0           NaN
#
#         WeatherDelay NASDelay  SecurityDelay  LateAircraftDelay
# 0                NaN      NaN            NaN                NaN
# 1                NaN      NaN            NaN                NaN
# 2                NaN      NaN            NaN                NaN
# 3                NaN      NaN            NaN                NaN
# 4                0.0      0.0            0.0               32.0
# 5                NaN      NaN            NaN                NaN
# 6                0.0      0.0            0.0               47.0
# 7                NaN      NaN            NaN                NaN
# 8                NaN      NaN            NaN                NaN
# 9                NaN      NaN            NaN                NaN
# 10               NaN      NaN            NaN                NaN
# 11               0.0      0.0            0.0               72.0
# 12               NaN      NaN            NaN                NaN
# 13               NaN      NaN            NaN                NaN
# 14               NaN      NaN            NaN                NaN
# 15               NaN      NaN            NaN                NaN
# 16               0.0      0.0            0.0               12.0
# 17               NaN      NaN            NaN                NaN
# 18               0.0      0.0            0.0               16.0
# 19               0.0      0.0            0.0               25.0
# 20               NaN      NaN            NaN                NaN
# 21               0.0      0.0            0.0               12.0
# 22               NaN      NaN            NaN                NaN
# 23               NaN      NaN            NaN                NaN
# 24               NaN      NaN            NaN                NaN
# 25               NaN      NaN            NaN                NaN
# 26               0.0      0.0            0.0                7.0
# 27               NaN      NaN            NaN                NaN
# 28               NaN      NaN            NaN                NaN
# 29               NaN      NaN            NaN                NaN
# ...              ...      ...            ...                ...
# 7009698          NaN      NaN            NaN                NaN
# 7009699          0.0      0.0            0.0               21.0
# 7009700          NaN      NaN            NaN                NaN
# 7009701          0.0     10.0            0.0               12.0
# 7009702          NaN      NaN            NaN                NaN
# 7009703          NaN      NaN            NaN                NaN
# 7009704          NaN      NaN            NaN                NaN
# 7009705          0.0     13.0            0.0                0.0
# 7009706          NaN      NaN            NaN                NaN
# 7009707          NaN      NaN            NaN                NaN
# 7009708          NaN      NaN            NaN                NaN
# 7009709          0.0      0.0            0.0               17.0
# 7009710          0.0      0.0            0.0               22.0
# 7009711          NaN      NaN            NaN                NaN
# 7009712          NaN      NaN            NaN                NaN
# 7009713          NaN      NaN            NaN                NaN
# 7009714          NaN      NaN            NaN                NaN
# 7009715          0.0     19.0            0.0                0.0
# 7009716          NaN      NaN            NaN                NaN
# 7009717         57.0     18.0            0.0                0.0
# 7009718          0.0     19.0            0.0               79.0
# 7009719          0.0     15.0            0.0                0.0
# 7009720          NaN      NaN            NaN                NaN
# 7009721          0.0     16.0            0.0                0.0
# 7009722          NaN      NaN            NaN                NaN
# 7009723          NaN      NaN            NaN                NaN
# 7009724          NaN      NaN            NaN                NaN
# 7009725          NaN      NaN            NaN                NaN
# 7009726          NaN      NaN            NaN                NaN
# 7009727          NaN      NaN            NaN                NaN
#
# [7009728 rows x 29 columns]

# %% [markdown]
# Избавляемся от пропусков:

# %%
new_data = data.dropna(subset=['CarrierDelay'])
new_data.shape
# Out:
# (1524735, 29)

# %%
new_data = data.dropna()
new_data.shape
# Out:
# (0, 29)

# %%
new_data.to_csv('has_carrier_delay.csv')

# %% [markdown]
# #### Работа со строками

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7009728 entries, 0 to 7009727
# Data columns (total 29 columns):
# Year                 int64
# Month                int64
# DayofMonth           int64
# DayOfWeek            int64
# DepTime              float64
# CRSDepTime           int64
# ArrTime              float64
# CRSArrTime           int64
# UniqueCarrier        object
# FlightNum            int64
# TailNum              object
# ActualElapsedTime    float64
# CRSElapsedTime       float64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Origin               object
# Dest                 object
# Distance             int64
# TaxiIn               float64
# TaxiOut              float64
# Cancelled            int64
# CancellationCode     object
# Diverted             int64
# CarrierDelay         float64
# WeatherDelay         float64
# NASDelay             float64
# SecurityDelay        float64
# LateAircraftDelay    float64
# dtypes: float64(14), int64(10), object(5)
# memory usage: 1.5+ GB

# %%
data.Origin.str.lower()
# Out:
# 0          iad
# 1          iad
# 2          ind
# 3          ind
# 4          ind
# 5          ind
# 6          ind
# 7          ind
# 8          ind
# 9          ind
# 10         ind
# 11         ind
# 12         ind
# 13         ind
# 14         ind
# 15         ind
# 16         ind
# 17         ind
# 18         ind
# 19         isp
# 20         isp
# 21         isp
# 22         isp
# 23         isp
# 24         isp
# 25         isp
# 26         isp
# 27         isp
# 28         isp
# 29         isp
#           ...
# 7009698    clt
# 7009699    ind
# 7009700    atl
# 7009701    slc
# 7009702    mci
# 7009703    atl
# 7009704    ind
# 7009705    atl
# 7009706    msy
# 7009707    atl
# 7009708    lex
# 7009709    hsv
# 7009710    msp
# 7009711    msy
# 7009712    slc
# 7009713    lax
# 7009714    sav
# 7009715    atl
# 7009716    atl
# 7009717    ric
# 7009718    atl
# 7009719    jax
# 7009720    msy
# 7009721    geg
# 7009722    sav
# 7009723    atl
# 7009724    atl
# 7009725    pbi
# 7009726    iad
# 7009727    sat
# Name: Origin, Length: 7009728, dtype: object

# %%
data.Origin.str[:2] + " " + data.Dest.str[:]
# Out:
# 0          IA TPA
# 1          IA TPA
# 2          IN BWI
# 3          IN BWI
# 4          IN BWI
# 5          IN JAX
# 6          IN LAS
# 7          IN LAS
# 8          IN MCI
# 9          IN MCI
# 10         IN MCO
# 11         IN MCO
# 12         IN MDW
# 13         IN MDW
# 14         IN MDW
# 15         IN MDW
# 16         IN PHX
# 17         IN PHX
# 18         IN TPA
# 19         IS BWI
# 20         IS BWI
# 21         IS BWI
# 22         IS BWI
# 23         IS BWI
# 24         IS BWI
# 25         IS BWI
# 26         IS FLL
# 27         IS FLL
# 28         IS FLL
# 29         IS LAS
#             ...
# 7009698    CL ATL
# 7009699    IN ATL
# 7009700    AT SDF
# 7009701    SL PHX
# 7009702    MC ATL
# 7009703    AT CHS
# 7009704    IN ATL
# 7009705    AT PBI
# 7009706    MS ATL
# 7009707    AT BDL
# 7009708    LE ATL
# 7009709    HS ATL
# 7009710    MS ATL
# 7009711    MS ATL
# 7009712    SL DEN
# 7009713    LA CVG
# 7009714    SA ATL
# 7009715    AT MCI
# 7009716    AT RSW
# 7009717    RI ATL
# 7009718    AT IAH
# 7009719    JA ATL
# 7009720    MS ATL
# 7009721    GE SLC
# 7009722    SA ATL
# 7009723    AT IAD
# 7009724    AT SAT
# 7009725    PB ATL
# 7009726    IA ATL
# 7009727    SA ATL
# dtype: object

# %% [markdown]
# # Matplotlib

# %% [markdown]
# Тьюториалы:
# - http://matplotlib.org/users/pyplot_tutorial.html
# - http://nbviewer.jupyter.org/github/jrjohansson/scientific-python-lectures/blob/master/Lecture-4-Matplotlib.ipynb
# - http://matplotlib.org/users/beginner.html
#
# Примеры (просто делайте ctrl+f тип нужного графика):
# - http://matplotlib.org/examples/pylab_examples/index.html
#
# Документация:
# - http://matplotlib.org/contents.html
#
# Matplotlib + Pandas:
# - http://pandas.pydata.org/pandas-docs/stable/visualization.html

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(1, 10, 20)
y = np.log(x)

# %%
plt.plot(x, y)

# %%
plt.scatter(x, y)

# %%
plt.plot(x, y, 'bo-')

# %%
data['AirTime'].hist()

# %%
data['AirTime'].hist(bins=30)

# %% [markdown]
# С группировкой:

# %%
cmp_data = pd.concat([data[data['Origin'] == 'ATL'], 
                      data[data['Origin'] == 'ORD']])
cmp_data['AirTime'].hist(by=cmp_data['Origin'], bins=30)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x122495978>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1505d9198>], dtype=object)

# %%
cmp_data['AirTime'].hist(by=cmp_data['Origin'], 
                         bins=30, sharey=True, sharex=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1506294e0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x14d537128>], dtype=object)

# %% [markdown]
# Как сделать то же самое в Matplotlib?

# %%
bins = 30
fig, axis = plt.subplots(1, 2, sharey=True, sharex=True)
axis[0].hist(cmp_data[cmp_data['Origin'] == 'ATL']['AirTime'].dropna(),
             bins=bins)
axis[0].set_xlabel('AirTime')
axis[0].set_ylabel('Scores')
axis[1].hist(cmp_data[cmp_data['Origin'] == 'ORD']['AirTime'].dropna(),
             bins=bins)
axis[1].set_xlabel('AirTime')

# %%
fig.clf()

# %%
bins = 30
index = np.arange(bins)
plt.hist(cmp_data[cmp_data['Origin'] == 'ATL']['AirTime'].dropna(),
         bins=bins, alpha=0.6)
plt.hist(cmp_data[cmp_data['Origin'] == 'ORD']['AirTime'].dropna(),
         bins=bins, alpha=0.6)
plt.xlabel('AirTime')
plt.ylabel('Scores')
plt.title('Comparison of ATL and ORD airports')
plt.legend(['ATL', 'ORD'])
plt.show()

# %%
bins = 30
index = np.arange(bins)
plt.hist(cmp_data[cmp_data['Origin'] == 'ATL']['AirTime'].dropna(),
         bins=bins, alpha=0.6, normed=True)
plt.hist(cmp_data[cmp_data['Origin'] == 'ORD']['AirTime'].dropna(),
         bins=bins, alpha=0.6, normed=True)
plt.xlabel('AirTime')
plt.ylabel('Scores')
plt.title('Comparison of ATL and ORD airports')
plt.legend(['ATL', 'ORD'])
plt.show()

# %%
plt.scatter(data['DepDelay'], data['ArrDelay'])
plt.xlabel('DepDelay')
plt.ylabel('ArrDelay')

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 2)
data_new = pca.fit_transform(data[['DepDelay', 'ArrDelay']].dropna())
print ('Component 1 explains %.2f of total variance'%pca.explained_variance_ratio_[0])
print ('Component 2 explains %.2f of total variance'%pca.explained_variance_ratio_[1])
plt.scatter(data['DepDelay'], data['ArrDelay'])
tg = pca.components_[0,1]/pca.components_[0,0]
plt.plot([data['DepDelay'].min(), data['DepDelay'].max()],
         [data['DepDelay'].min() * tg, data['DepDelay'].max() * tg], color='green')
plt.plot([data['DepDelay'].min(), data['DepDelay'].max()],
         [data['ArrDelay'].min(), data['ArrDelay'].max()], color = 'red')
plt.legend(['Regression that accounts variance', 'Obvious regression'], loc=4)
# Out:
# Component 1 explains 0.97 of total variance
# Component 2 explains 0.03 of total variance

# %% [markdown]
# # Задания

# %% [markdown]
# По векторным операциям:
# 1. Найдите несколькими способами диагональ матричного произведения
# 2. Вставьте между каждым числом в заданном векторе четыре нуля
# 3. Найдите ближайшее значение в массиве к заданному
# 4. Найдите ближайшую строчку в массиве к заданной
#
# По датасету flights:
# 1. Найдите рейс (FlightNum) с максимальной длиной перелетов. Уникален ли такой рейс?
# 2. Найдите для каждого аэропорта среднее время полета (AirTime) по всем вылетевшим из него рейсам. Какой аэропорт имеет наибольшее значение этого показателя?
# 3. Найдите аэропорт, у которого наибольшая доля задержанных (DepDelay > 0) рейсов. Исключите при этом из рассмотрения аэропорты, из которых было отправлено меньше 1000 рейсов (используйте функцию filter после groupby).

# %%
max_d = data['Distance'].max()
data[data['Distance'] == max_d]["FlightNum"].unique()
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 563198   2008      1          27          7   2233.0        2245   1253.0
# 563743   2008      1          30          3   2230.0        2245   1259.0
# 564451   2008      1          17          4   2232.0        2245   1245.0
# 564683   2008      1          14          1   1331.0        1320   1905.0
# 565483   2008      1           3          4   2236.0        2245   1305.0
# 566384   2008      1          15          2   1334.0        1320   1932.0
# 566426   2008      1          13          7   1326.0        1320   1912.0
# 566444   2008      1          31          4   2237.0        2245   1316.0
# 566524   2008      1          15          2   2237.0        2245   1303.0
# 566875   2008      1          11          5   1344.0        1320   1947.0
# 567073   2008      1          12          6   2238.0        2245   1316.0
# 567604   2008      1          16          3   2237.0        2245   1356.0
# 567811   2008      1           6          7   1330.0        1320   1915.0
# 567953   2008      1           6          7   2237.0        2245   1251.0
# 569303   2008      1          18          5   2234.0        2245   1257.0
# 569600   2008      1          11          5   2245.0        2245   1302.0
# 570159   2008      1           7          1   2246.0        2245   1256.0
# 570303   2008      1          20          7   1332.0        1320   1939.0
# 570350   2008      1          22          2   1441.0        1320   2016.0
# 570767   2008      1           1          2   2239.0        2245   1338.0
# 571327   2008      1          27          7   1317.0        1320   1911.0
# 571583   2008      1          23          3   1440.0        1320   1954.0
# 572083   2008      1           4          5   1339.0        1320   1940.0
# 572217   2008      1           2          3   2239.0        2245   1343.0
# 572311   2008      1          10          4   1320.0        1320   1925.0
# 573078   2008      1           3          4   1325.0        1320   1922.0
# 573109   2008      1          18          5   1402.0        1320   1926.0
# 573113   2008      1          22          2   2235.0        2245   1249.0
# 573258   2008      1          24          4   2230.0        2245   1252.0
# 573775   2008      1          28          1   1359.0        1320   1928.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 6980182  2008     12          19          5      5.0        2055   1433.0
# 6980183  2008     12          19          5   1407.0        1335   2217.0
# 6980978  2008     12          18          4   2051.0        2055   1109.0
# 6980979  2008     12          18          4   1337.0        1335   1951.0
# 6981771  2008     12          17          3   2143.0        2055   1225.0
# 6981772  2008     12          17          3   1443.0        1335   2036.0
# 6982535  2008     12          16          2   2135.0        2055   1148.0
# 6982536  2008     12          16          2   1359.0        1335   2022.0
# 6983222  2008     12          15          1   2055.0        2055   1048.0
# 6983223  2008     12          15          1   1401.0        1335   1950.0
# 6984688  2008     12          13          6   2056.0        2055   1113.0
# 6984689  2008     12          13          6   1340.0        1335   1924.0
# 6985263  2008     12          12          5   2108.0        2055   1124.0
# 6985264  2008     12          12          5   1418.0        1335   1951.0
# 6986028  2008     12          11          4   2058.0        2055   1149.0
# 6986029  2008     12          11          4   1503.0        1335   2028.0
# 6988170  2008     12           8          1    104.0        2055   1619.0
# 6988171  2008     12           8          1   1346.0        1335   1923.0
# 6988940  2008     12           7          7   2051.0        2055   1128.0
# 6988941  2008     12           7          7   1435.0        1335   2012.0
# 6989640  2008     12           6          6   2100.0        2055   1116.0
# 6989641  2008     12           6          6   1344.0        1335   1911.0
# 6990215  2008     12           5          5   2058.0        2055   1127.0
# 6990216  2008     12           5          5   1428.0        1335   1937.0
# 6991744  2008     12           3          3   2105.0        2055   1134.0
# 6991745  2008     12           3          3   1441.0        1335   2005.0
# 6992437  2008     12           2          2   2052.0        2055   1124.0
# 6992438  2008     12           2          2   1435.0        1335   2013.0
# 6993152  2008     12           1          1   2059.0        2055   1138.0
# 6993153  2008     12           1          1   1340.0        1335   1929.0
#
#          CRSArrTime UniqueCarrier  FlightNum        ...         TaxiIn  \
# 563198         1310            CO         14        ...            7.0
# 563743         1310            CO         14        ...            8.0
# 564451         1310            CO         14        ...           13.0
# 564683         1920            CO         15        ...            8.0
# 565483         1310            CO         14        ...           11.0
# 566384         1920            CO         15        ...            9.0
# 566426         1920            CO         15        ...           10.0
# 566444         1310            CO         14        ...            5.0
# 566524         1310            CO         14        ...           10.0
# 566875         1920            CO         15        ...            6.0
# 567073         1310            CO         14        ...           10.0
# 567604         1310            CO         14        ...           16.0
# 567811         1920            CO         15        ...            8.0
# 567953         1310            CO         14        ...            7.0
# 569303         1310            CO         14        ...            7.0
# 569600         1310            CO         14        ...            8.0
# 570159         1310            CO         14        ...            9.0
# 570303         1920            CO         15        ...           10.0
# 570350         1920            CO         15        ...            6.0
# 570767         1310            CO         14        ...            5.0
# 571327         1920            CO         15        ...            3.0
# 571583         1920            CO         15        ...            8.0
# 572083         1920            CO         15        ...            8.0
# 572217         1310            CO         14        ...           18.0
# 572311         1920            CO         15        ...            8.0
# 573078         1920            CO         15        ...            6.0
# 573109         1920            CO         15        ...            6.0
# 573113         1310            CO         14        ...           14.0
# 573258         1310            CO         14        ...            9.0
# 573775         1920            CO         15        ...            7.0
# ...             ...           ...        ...        ...            ...
# 6980182        1120            CO         14        ...           19.0
# 6980183        1935            CO         15        ...            9.0
# 6980978        1120            CO         14        ...            7.0
# 6980979        1935            CO         15        ...           10.0
# 6981771        1120            CO         14        ...           29.0
# 6981772        1935            CO         15        ...           10.0
# 6982535        1120            CO         14        ...           13.0
# 6982536        1935            CO         15        ...            7.0
# 6983222        1120            CO         14        ...            9.0
# 6983223        1935            CO         15        ...            8.0
# 6984688        1120            CO         14        ...           12.0
# 6984689        1935            CO         15        ...            6.0
# 6985263        1120            CO         14        ...            9.0
# 6985264        1935            CO         15        ...            9.0
# 6986028        1120            CO         14        ...           22.0
# 6986029        1935            CO         15        ...            6.0
# 6988170        1120            CO         14        ...           13.0
# 6988171        1935            CO         15        ...            8.0
# 6988940        1120            CO         14        ...           11.0
# 6988941        1935            CO         15        ...            6.0
# 6989640        1120            CO         14        ...            8.0
# 6989641        1935            CO         15        ...            8.0
# 6990215        1120            CO         14        ...            8.0
# 6990216        1935            CO         15        ...            4.0
# 6991744        1120            CO         14        ...           12.0
# 6991745        1935            CO         15        ...            7.0
# 6992437        1120            CO         14        ...           12.0
# 6992438        1935            CO         15        ...           10.0
# 6993152        1120            CO         14        ...           13.0
# 6993153        1935            CO         15        ...            7.0
#
#          TaxiOut  Cancelled  CancellationCode  Diverted  CarrierDelay  \
# 563198      17.0          0               NaN         0           NaN
# 563743      26.0          0               NaN         0           NaN
# 564451      19.0          0               NaN         0           NaN
# 564683      21.0          0               NaN         0           NaN
# 565483      28.0          0               NaN         0           NaN
# 566384      32.0          0               NaN         0           NaN
# 566426      15.0          0               NaN         0           NaN
# 566444      16.0          0               NaN         0           NaN
# 566524      14.0          0               NaN         0           NaN
# 566875      28.0          0               NaN         0          24.0
# 567073      19.0          0               NaN         0           NaN
# 567604      29.0          0               NaN         0           0.0
# 567811      21.0          0               NaN         0           NaN
# 567953      20.0          0               NaN         0           NaN
# 569303      18.0          0               NaN         0           NaN
# 569600      21.0          0               NaN         0           NaN
# 570159      17.0          0               NaN         0           NaN
# 570303      31.0          0               NaN         0           0.0
# 570350      22.0          0               NaN         0           0.0
# 570767      16.0          0               NaN         0           0.0
# 571327      23.0          0               NaN         0           NaN
# 571583      17.0          0               NaN         0          34.0
# 572083      17.0          0               NaN         0           0.0
# 572217      24.0          0               NaN         0           0.0
# 572311      30.0          0               NaN         0           NaN
# 573078      30.0          0               NaN         0           NaN
# 573109      18.0          0               NaN         0           NaN
# 573113      17.0          0               NaN         0           NaN
# 573258      20.0          0               NaN         0           NaN
# 573775      20.0          0               NaN         0           NaN
# ...          ...        ...               ...       ...           ...
# 6980182     17.0          0               NaN         0          18.0
# 6980183    147.0          0               NaN         0           0.0
# 6980978     18.0          0               NaN         0           NaN
# 6980979     17.0          0               NaN         0           0.0
# 6981771     22.0          0               NaN         0           0.0
# 6981772     22.0          0               NaN         0           0.0
# 6982535     17.0          0               NaN         0           0.0
# 6982536     39.0          0               NaN         0          24.0
# 6983222     17.0          0               NaN         0           NaN
# 6983223     22.0          0               NaN         0          15.0
# 6984688     21.0          0               NaN         0           NaN
# 6984689     13.0          0               NaN         0           NaN
# 6985263     18.0          0               NaN         0           NaN
# 6985264     18.0          0               NaN         0           0.0
# 6986028     19.0          0               NaN         0           0.0
# 6986029     20.0          0               NaN         0           0.0
# 6988170     19.0          0               NaN         0         249.0
# 6988171     21.0          0               NaN         0           NaN
# 6988940     17.0          0               NaN         0           NaN
# 6988941     21.0          0               NaN         0           0.0
# 6989640     16.0          0               NaN         0           NaN
# 6989641     10.0          0               NaN         0           NaN
# 6990215     20.0          0               NaN         0           NaN
# 6990216     14.0          0               NaN         0           NaN
# 6991744     21.0          0               NaN         0           NaN
# 6991745     18.0          0               NaN         0           0.0
# 6992437     18.0          0               NaN         0           NaN
# 6992438     18.0          0               NaN         0          38.0
# 6993152     18.0          0               NaN         0           0.0
# 6993153     27.0          0               NaN         0           NaN
#
#         WeatherDelay NASDelay  SecurityDelay  LateAircraftDelay
# 563198           NaN      NaN            NaN                NaN
# 563743           NaN      NaN            NaN                NaN
# 564451           NaN      NaN            NaN                NaN
# 564683           NaN      NaN            NaN                NaN
# 565483           NaN      NaN            NaN                NaN
# 566384           NaN      NaN            NaN                NaN
# 566426           NaN      NaN            NaN                NaN
# 566444           NaN      NaN            NaN                NaN
# 566524           NaN      NaN            NaN                NaN
# 566875           0.0      3.0            0.0                0.0
# 567073           NaN      NaN            NaN                NaN
# 567604           0.0     46.0            0.0                0.0
# 567811           NaN      NaN            NaN                NaN
# 567953           NaN      NaN            NaN                NaN
# 569303           NaN      NaN            NaN                NaN
# 569600           NaN      NaN            NaN                NaN
# 570159           NaN      NaN            NaN                NaN
# 570303           0.0      7.0            0.0               12.0
# 570350           0.0      0.0            0.0               56.0
# 570767           0.0     28.0            0.0                0.0
# 571327           NaN      NaN            NaN                NaN
# 571583           0.0      0.0            0.0                0.0
# 572083           0.0      1.0            0.0               19.0
# 572217           0.0     33.0            0.0                0.0
# 572311           NaN      NaN            NaN                NaN
# 573078           NaN      NaN            NaN                NaN
# 573109           NaN      NaN            NaN                NaN
# 573113           NaN      NaN            NaN                NaN
# 573258           NaN      NaN            NaN                NaN
# 573775           NaN      NaN            NaN                NaN
# ...              ...      ...            ...                ...
# 6980182          0.0      3.0            0.0              172.0
# 6980183         32.0    130.0            0.0                0.0
# 6980978          NaN      NaN            NaN                NaN
# 6980979          0.0     16.0            0.0                0.0
# 6981771          0.0     17.0            0.0               48.0
# 6981772          0.0      0.0            0.0               61.0
# 6982535          0.0      0.0            0.0               28.0
# 6982536          0.0     23.0            0.0                0.0
# 6983222          NaN      NaN            NaN                NaN
# 6983223          0.0      0.0            0.0                0.0
# 6984688          NaN      NaN            NaN                NaN
# 6984689          NaN      NaN            NaN                NaN
# 6985263          NaN      NaN            NaN                NaN
# 6985264          0.0      0.0            0.0               16.0
# 6986028          0.0     29.0            0.0                0.0
# 6986029         53.0      0.0            0.0                0.0
# 6988170          0.0     50.0            0.0                0.0
# 6988171          NaN      NaN            NaN                NaN
# 6988940          NaN      NaN            NaN                NaN
# 6988941          0.0      0.0            0.0               37.0
# 6989640          NaN      NaN            NaN                NaN
# 6989641          NaN      NaN            NaN                NaN
# 6990215          NaN      NaN            NaN                NaN
# 6990216          NaN      NaN            NaN                NaN
# 6991744          NaN      NaN            NaN                NaN
# 6991745          0.0      0.0            0.0               30.0
# 6992437          NaN      NaN            NaN                NaN
# 6992438          0.0      0.0            0.0                0.0
# 6993152          0.0     18.0            0.0                0.0
# 6993153          NaN      NaN            NaN                NaN
#
# [724 rows x 29 columns]
